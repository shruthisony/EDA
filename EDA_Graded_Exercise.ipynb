# %% [markdown]
# ##Necessary Modules

# %%
#Import the required Libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Data Reading & Data Types

# %%
#Read the data in pandas
inp0= pd.read_csv("Attribute+DataSet.csv")
inp1= pd.read_csv("Dress+Sales.csv")

# %% [markdown]
# You have “Attribute DataSet” which contains a column named “Price”. Choose the correct statement from the following about its data type and variable type.
# - Integer type and numerical variable
# - Object type and categorical ordinal variable
# - Object type and categorical nominal variable
# - Float type and categorical variable.

# %%
inp0['Price'].dtypes
# Out:
# dtype('O')

# %%
inp0['Price'].unique()
# Out:
# array(['Low', 'High', 'Average', 'Medium', 'very-high', nan], dtype=object)

# %%
inp0['Price'].value_counts()
# Out:
# Price
# Average      240
# Low          165
# Medium        30
# High          21
# very-high     21
# Name: count, dtype: int64

# %% [markdown]
# There is another column in “Attribute DataSet” named as “Recommendation”, choose the correct statement about its data type and variable type.
# - Integer type and categorical
# - Object type and categorical
# - Integer type and continuous numerical
# - Object type only.

# %%
inp0['Recommendation'].dtypes
# Out:
# dtype('int64')

# %%
inp0['Recommendation'].value_counts()
# Out:
# Recommendation
# 0    274
# 1    205
# Name: count, dtype: int64

# %%
inp0['Recommendation'].unique()
# Out:
# array([1, 0])

# %% [markdown]
# Which of the following column do you think are of no use in “Attribute DataSet”.
# - Dress_ID
# - Price
# - Size and material
# - NeckLine
# - None of the above

# %%
# Print the information about the attributes of inp0 and inp1.
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %% [markdown]
# ### Fixing the Rows and Columns

# %% [markdown]
# As you can see, there is a column in “Attribute Dataset” named as ‘Size’. This column contains the values in abbreviation format. Write a code in Python to convert the followings:
#
# - M into  “Medium”
# - L into  “Large”
# - XL into “Extra large”
# - free into “Free”
# - S, s & small into “Small”.
#
# Now once you are done with changes in the dataset, what is the value of the lowest percentage, the highest percentage and the percentage of Small size categories in the column named “Size”?

# %%
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# dtype: int64

# %%
inp0.Size= inp0.Size.replace(['S', 'small', 's'], "Small")

inp0.Size= inp0.Size.replace('free', "Free")

inp0.Size= inp0.Size.replace('M', "Medium")

inp0.Size= inp0.Size.replace('L', "Large")

inp0.Size= inp0.Size.replace('XL', "Extra large")

# %%
# Column fixing, correcting size abbreviation. count the percentage of each size category in "Size" column.
inp0['Size'].value_counts()
# Out:
# Size
# Medium         171
# Free           165
# Large           93
# Small           36
# Extra large     14
# Name: count, dtype: int64

# %%
# Print the value counts of each category in "Size" column.
print('Smallest: ',14/479 * 100.0)
print('Highest: ',171/479 * 100.0)
print('Only Small: ',36/479 * 100.0)
# Out:
# Smallest:  2.9227557411273484
# Highest:  35.699373695198325
# Only Small:  7.515657620041753

# %%
inp0.Size.value_counts(normalize=True)
# Out:
# Size
# Medium         0.356994
# Free           0.344468
# Large          0.194154
# Small          0.075157
# Extra large    0.029228
# Name: proportion, dtype: float64

# %% [markdown]
# ### Impute/Remove Missing values

# %%
# Print the null count of each variables of inp0 and inp1.
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# dtype: int64

# %%
inp1.isnull().sum()
# Out:
# Dress_ID        0
# 29-08-2013      0
# 31-08-2013      0
# 09-02-2013      0
# 09-04-2013      0
# 09-06-2013      0
# 09-08-2013      0
# 09-10-2013      0
# 09-12-2013      0
# 14-09-2013      0
# 16-09-2013      0
# 18-09-2013      0
# 20-09-2013      0
# 22-09-2013      0
# 24-09-2013      0
# 26-09-2013    222
# 28-09-2013      0
# 30-09-2013    257
# 10-02-2013    259
# 10-04-2013    258
# 10-06-2013      0
# 10-08-2013    255
# 10-10-2013    255
# 10-12-2013      0
# dtype: int64

# %% [markdown]
# You are given another dataset named “Dress Sales”. Now if you observe the datatypes of the columns using ‘inp1.info()’ command, you can identify that there are certain columns defined as object data type though they primarily consist of numeric data.
#
# Now if you try and convert these object data type columns into numeric data type(float), you will come across an error message. Try to correct this error.

# %%
# Print the data types information of inp1 i.e. "Dress Sales" data.
inp1.dtypes
# Out:
# Dress_ID      float64
# 29-08-2013      int64
# 31-08-2013      int64
# 09-02-2013      int64
# 09-04-2013      int64
# 09-06-2013      int64
# 09-08-2013      int64
# 09-10-2013      int64
# 09-12-2013     object
# 14-09-2013     object
# 16-09-2013     object
# 18-09-2013     object
# 20-09-2013     object
# 22-09-2013     object
# 24-09-2013      int64
# 26-09-2013    float64
# 28-09-2013      int64
# 30-09-2013    float64
# 10-02-2013    float64
# 10-04-2013    float64
# 10-06-2013      int64
# 10-08-2013    float64
# 10-10-2013    float64
# 10-12-2013      int64
# dtype: object

# %%
# Try to convert the object type into float type of data. YOU GET ERROR MESSAGE.
#inp1['09-12-2013'].astype('float')

# %%
# Do the required changes in the "Dress Sales" data set to get null values on string values.
#inp1[inp1['09-12-2013']=='Removed']
'''09-12-2013     object
14-09-2013     object
16-09-2013     object
18-09-2013     object
20-09-2013     object
22-09-2013     object'''
inp1['09-12-2013'] = inp1['09-12-2013'].apply(lambda x: x.replace('Removed',''))

# %%
inp1['14-09-2013'] = inp1['14-09-2013'].apply(lambda x: x.replace('Removed',''))
inp1['16-09-2013'] = inp1['16-09-2013'].apply(lambda x: x.replace('Removed',''))
inp1['18-09-2013'] = inp1['18-09-2013'].apply(lambda x: x.replace('Removed',''))
inp1['20-09-2013'] = inp1['20-09-2013'].apply(lambda x: x.replace('Removed',''))
inp1['22-09-2013'] = inp1['22-09-2013'].apply(lambda x: x.replace('Removed',''))

# %%
# Convert the object type columns in "Dress Sales" into float type of data type.
inp1[inp1['09-12-2013']=='Removed']
# Out:
# Empty DataFrame
# Columns: [Dress_ID, 29-08-2013, 31-08-2013, 09-02-2013, 09-04-2013, 09-06-2013, 09-08-2013, 09-10-2013, 09-12-2013, 14-09-2013, 16-09-2013, 18-09-2013, 20-09-2013, 22-09-2013, 24-09-2013, 26-09-2013, 28-09-2013, 30-09-2013, 10-02-2013, 10-04-2013, 10-06-2013, 10-08-2013, 10-10-2013, 10-12-2013]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# When you see the null counts in “Dress Sales” dataset after performing all the operations that have been mentioned in jupyter notebook, you will find that there are some columns in “Dress Sales” data where there are more than 40% of missing values. Based on your understanding of dealing with missing values do the following steps.

# %%
# Print the null percetange of each column of inp1.
inp1.isnull().sum()
# Out:
# Dress_ID        0
# 29-08-2013      0
# 31-08-2013      0
# 09-02-2013      0
# 09-04-2013      0
# 09-06-2013      0
# 09-08-2013      0
# 09-10-2013      0
# 09-12-2013      0
# 14-09-2013      0
# 16-09-2013      0
# 18-09-2013      0
# 20-09-2013      0
# 22-09-2013      0
# 24-09-2013      0
# 26-09-2013    222
# 28-09-2013      0
# 30-09-2013    257
# 10-02-2013    259
# 10-04-2013    258
# 10-06-2013      0
# 10-08-2013    255
# 10-10-2013    255
# 10-12-2013      0
# dtype: int64

# %%
inp1.shape
# Out:
# (479, 24)

# %%
'''
These are the columns with more than 40% of null values . so drop these columns
26-09-2013    222
30-09-2013    257
10-02-2013    259
10-04-2013    258
10-08-2013    255
10-10-2013    255'''
222/479 * 100.0
# Out:
# 46.34655532359081

# %%
# Drop the columns in "Dress Sales" which have more than 40% of missing values.
inp1.drop('26-09-2013',axis=1,inplace=True)
inp1.drop('30-09-2013',axis=1,inplace=True)
inp1.drop('10-02-2013',axis=1,inplace=True)
inp1.drop('10-04-2013',axis=1,inplace=True)
inp1.drop('10-08-2013',axis=1,inplace=True)
inp1.drop('10-10-2013',axis=1,inplace=True)

# %%
inp1.shape
# Out:
# (479, 18)

# %% [markdown]
# You should categorise the dates into seasons in “Dress Sales” data to simplify the analysis according to the following criteria:
# - June, July and August: Summer.
# - September, October and November: Autumn.
# - December, January and February: WInter.
# - March, April and May: Spring.

# %%
# Try to convert the object type into float type of data. YOU MIGHT GET AN ERROR MESSAGE.
inp1["09-12-2013"] = inp1["09-12-2013"].apply(pd.to_numeric, downcast='float', errors='coerce')
inp1["14-09-2013"] = inp1["14-09-2013"].apply(pd.to_numeric, downcast='float', errors='coerce')
inp1["16-09-2013"] = inp1["16-09-2013"].apply(pd.to_numeric, downcast='float', errors='coerce')
inp1["18-09-2013"] = inp1["18-09-2013"].apply(pd.to_numeric, downcast='float', errors='coerce')
inp1["20-09-2013"] = inp1["20-09-2013"].apply(pd.to_numeric, downcast='float', errors='coerce')
inp1["22-09-2013"] = inp1["22-09-2013"].apply(pd.to_numeric, downcast='float', errors='coerce')

# %%
inp1['Spring'] = inp1.apply(lambda x: x['09-04-2013'], axis=1)

# %%
inp1['Summer'] =  inp1['29-08-2013'] + inp1['31-08-2013']+ inp1['09-06-2013']+ inp1['09-08-2013']+ inp1['10-06-2013']

# %%
inp1['Winter'] = inp1['09-02-2013'] + inp1['09-12-2013']+ inp1['10-12-2013']

# %%
inp1['Autumn'] = inp1.apply(lambda x: x['09-10-2013'] + x['14-09-2013']+ x['16-09-2013']+ x['18-09-2013']+ x['20-09-2013']+ x['22-09-2013']+ x['24-09-2013']+ x['28-09-2013'], axis=1)

# %%
inp1.head()
# Out:
#        Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0  1.006033e+09        2114        2274        2491        2660        2727
# 1  1.212192e+09         151         275         570         750         813
# 2  1.190381e+09           6           7           7           7           8
# 3  9.660060e+08        1005        1128        1326        1455        1507
# 4  8.763395e+08         996        1175        1304        1396        1432
#
#    09-08-2013  09-10-2013  09-12-2013  14-09-2013  ...  20-09-2013  \
# 0        2887        2930      3119.0      3204.0  ...      3386.0
# 1        1066        1164      1558.0      1756.0  ...      2106.0
# 2           8           9        10.0        10.0  ...        10.0
# 3        1621        1637      1723.0      1746.0  ...      1812.0
# 4        1559        1570      1638.0      1655.0  ...      1824.0
#
#    22-09-2013  24-09-2013  28-09-2013  10-06-2013  10-12-2013  Spring  Summer  \
# ...

# %%
# calculate the sum of sales in each seasons in inp1 i.e. "Dress Sales".
print('Summer:',inp1['Summer'].sum())
print('Spring:',inp1['Spring'].sum())
print('Winter:',inp1['Winter'].sum())
print('Autumn:',inp1['Autumn'].sum())
# Out:
# Summer: 691907
# Spring: 143600.0
# Winter: 473640.0
# Autumn: 1353543.0

# %% [markdown]
# Now let's merge inp1 with inp0 with left join manner, so that the information of inp0 should remain intact.

# %%
# Merge inp0 with inp1 into inp0. this is also called left merge.
inp0 = pd.merge(left=inp0,right=inp1, how='left', left_on='Dress_ID', right_on='Dress_ID')
inp0.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0   Large  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck         full
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck    butterfly
#
#         Material FabricType  ... 20-09-2013 22-09-2013  24-09-2013  \
# 0            NaN    chiffon  ...     3386.0     3479.0        3554
# 1     microfiber        NaN  ...     2106.0     2454.0        2710
# 2       polyster        NaN  ...       10.0       11.0          11
# 3           silk    chiffon  ...     1812.0     1845.0        1878
# 4  chiffonfabric    chiffon  ...     1824.0     1919.0        2032
#
#    28-09-2013  10-06-2013  10-12-2013  Spring  Summer  Winter   Autumn
# ...

# %%
# Now Drop the Date columns from inp0 as it is already combined into four seasons.
inp0.drop(inp0.loc[:,'29-08-2013':'10-12-2013'].columns, axis= 1, inplace= True)
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# Spring              0
# Summer              0
# Winter              1
# Autumn              2
# dtype: int64

# %% [markdown]
# Print the null count of inp0 to get the idea about the missing values in data set.

# %%
# Print the null count of each columns in inp0 dataframe i.e. combined data frame of inp0 and inp1 without date columns.
inp0.isnull().sum()
# Out:
# Dress_ID            0
# Style               0
# Price               2
# Rating              0
# Size                0
# Season              2
# NeckLine            3
# SleeveLength        2
# Material          119
# FabricType        256
# Decoration        224
# Pattern Type      102
# Recommendation      0
# Spring              0
# Summer              0
# Winter              1
# Autumn              2
# dtype: int64

# %% [markdown]
# You can see that there are two types of variables one with a large number of missing values and another is very less number of missing values. These two columns can be categorized as:
#
# Type-1: Missing values are very less (around 2 or 3 missing values): Price, Season, NeckLine, SleeveLength, Winter and Autumn.
#
# Type-2: Missing values are large in numbers (more than 15%): Material, FabricType, Decoration and Pattern Type.

# %%
# Deal with the missing values of Type-1 columns: Price, Season, NeckLine, SleeveLength, Winter and Autumn.
inp0.dropna(subset=['Price', 'Season', 'NeckLine', 'SleeveLength', 'Winter', 'Autumn'],axis=0,inplace=True)

# %%
# Deal with the missing values for Type-2 columns: Material, FabricType, Decoration and Pattern Type.
inp0['Material'].fillna('Missing',inplace=True)
inp0['FabricType'].fillna('Missing',inplace=True)
inp0['Decoration'].fillna('Missing',inplace=True)
inp0['Pattern Type'].fillna('Missing Type',inplace=True)

# %%
inp0.isnull().sum()
# Out:
# Dress_ID          0
# Style             0
# Price             0
# Rating            0
# Size              0
# Season            0
# NeckLine          0
# SleeveLength      0
# Material          0
# FabricType        0
# Decoration        0
# Pattern Type      0
# Recommendation    0
# Spring            0
# Summer            0
# Winter            0
# Autumn            0
# dtype: int64

# %% [markdown]
# ### Standardise value

# %% [markdown]
# In the given dataset, there are certain discrepancies with the categorical names such as irregular spellings. Choose the correct option of columns with irregular categories and update them.
#
# - Season, NeckLine
# - Price, Material
# - fabricType, Decoration
# - Season, SleeveLength

# %%
#correcting the spellings.
inp0['Season'].value_counts()
# Out:
# Season
# Summer    151
# Spring    116
# Winter     92
# Automn     59
# winter     44
# Autumn      7
# spring      2
# Name: count, dtype: int64

# %%
inp0['Season'] = inp0['Season'].apply(lambda x: x.replace('Automn','Autumn').replace('winter','Winter').replace('spring','Spring'))

# %%
inp0['Season'].value_counts()
# Out:
# Season
# Summer    151
# Winter    136
# Spring    118
# Autumn     66
# Name: count, dtype: int64

# %%
#correcting the Spellings.
inp0['SleeveLength'].value_counts()
# Out:
# SleeveLength
# sleevless         213
# short              92
# full               91
# halfsleeve         32
# threequarter       17
# thressqatar         8
# sleeveless          4
# capsleeves          3
# sleeevless          2
# cap-sleeves         2
# urndowncollor       1
# half                1
# turndowncollor      1
# threequater         1
# Petal               1
# butterfly           1
# sleveless           1
# Name: count, dtype: int64

# %%
inp0.SleeveLength= inp0.SleeveLength.replace(['cap-sleeves', 'capsleeves'], "cap sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace('full', "full sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace(['half','halfsleeve'], "half sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace(['sleevless', 'sleeevless', 'sleeveless', 'sleveless'], "sleeve less")

inp0.SleeveLength= inp0.SleeveLength.replace(['threequarter','threequater', 'thressqatar'], "three quater")

inp0.SleeveLength= inp0.SleeveLength.replace(['turndowncollor','urndowncollor'], "turn down collar")

# %%
inp0['SleeveLength'].value_counts()
# Out:
# SleeveLength
# sleeve less         220
# short                92
# full sleeves         91
# half sleeves         33
# three quater         26
# cap sleeves           5
# turn down collar      2
# Petal                 1
# butterfly             1
# Name: count, dtype: int64

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical Unordered Univariate Analysis

# %% [markdown]
# There is a column named ‘Style’ in ‘Attribute Dataset’ which consists of the different style categories of the women apparels. Certain categories whose total sale is less than 50000 across all the seasons is considered under one single category as ‘Others’.

# %% [markdown]
# Which of the following categories in ‘Style’ column can be grouped into ‘Others’ category? and perform the grouping operation in the notebook for further analysis.
# - Flare, fashion
# - Novelty, bohemian
# - OL, fashion, work
# - Novelty, fashion, Flare

# %%
# Group "Style" categories into "Others" which have less than 50000 sales across all the seasons.
totstyle = inp0.groupby(['Style'])[['Spring','Winter','Autumn','Summer']].sum()

# %%
totstyle
# Out:
#            Spring    Winter    Autumn  Summer
# Style
# Brief      7484.0   25020.0   69821.0   37303
# Casual    60979.0  192922.0  566744.0  282913
# Flare        71.0     406.0    1161.0     451
# Novelty     563.0    2504.0    7353.0    2866
# OL           15.0      53.0     158.0      63
# Sexy      23451.0   81263.0  230524.0  117117
# bohemian   3800.0   11752.0   37446.0   16119
# cute      20022.0   63999.0  179466.0   98512
# fashion      19.0      74.0     211.0      91
# party      7987.0   24558.0   73978.0   35518
# sexy       3564.0   15173.0   39002.0   19704
# vintage    8693.0   33595.0   91439.0   46847
# work       4893.0   16882.0   46389.0   24931

# %%
totstyle.sum(axis=1)
# Out:
# Style
# Brief        139628.0
# Casual      1103558.0
# Flare          2089.0
# Novelty       13286.0
# OL              289.0
# Sexy         452355.0
# bohemian      69117.0
# cute         361999.0
# fashion         395.0
# party        142041.0
# sexy          77443.0
# vintage      180574.0
# work          93095.0
# dtype: float64

# %%
totstyle.loc['Novelty'].sum()
# Out:
# 13286.0

# %%
totstyle.loc['Flare'].sum()
# Out:
# 2089.0

# %%
totstyle.loc['fashion'].sum()
# Out:
# 395.0

# %% [markdown]
# What is the percentage of “cute” and “Others” category in “Style” column in “Attribute DataSet” respectively?
# - 46%, 5%
# - 9%, 2.1%
# - 2.1%, 5%
# - 13.8%, 9%

# %%
# Calculate the percentage of each categories in the "Style" variable.
inp0['Style'].value_counts(normalize=True)*100
# Out:
# Style
# Casual      46.072187
# Sexy        13.800425
# party       10.191083
# cute         9.129512
# vintage      5.307856
# bohemian     4.883227
# Brief        3.609342
# work         3.609342
# sexy         1.273885
# Novelty      1.273885
# Flare        0.424628
# OL           0.212314
# fashion      0.212314
# Name: proportion, dtype: float64

# %%
inp0.Style.value_counts(normalize=True).plot.barh()
plt.show()

# %% [markdown]
# Similarly Club Neckline, SLeeve length categories into "Others" which have less than 50000 sales across all the seasons.

# %%
# Group "Neckline" categories into "Others" which have less than 50000 sales across all the seasons.
totneckline = inp0.groupby(by=['NeckLine','SleeveLength'])[['Spring','Summer','Winter','Autumn']].sum()
totneckline
# Out:
#                                    Spring  Summer    Winter    Autumn
# NeckLine        SleeveLength
# Scoop           short               198.0     657     478.0    1802.0
# Sweetheart      sleeve less         911.0    3072    2264.0    8341.0
# backless        sleeve less         190.0     600     408.0    1690.0
# boat-neck       full sleeves       1774.0    8436    5630.0   15808.0
#                 short               213.0    1466    1240.0    4112.0
#                 sleeve less         797.0    3130    2395.0    8048.0
# bowneck         full sleeves         68.0     273     221.0     746.0
#                 half sleeves          1.0       5       4.0      21.0
#                 short                62.0     430     420.0    1154.0
#                 sleeve less        1194.0    3875    2709.0   10450.0
# halter          sleeve less         151.0     505     363.0    1336.0
# mandarin-collor half sleeves         15.0      63      53.0     158.0
# ...

# %%
totneckline[totneckline.sum(axis=1)<50000]
# Out:
#                                   Spring  Summer  Winter   Autumn
# NeckLine        SleeveLength
# Scoop           short              198.0     657   478.0   1802.0
# Sweetheart      sleeve less        911.0    3072  2264.0   8341.0
# backless        sleeve less        190.0     600   408.0   1690.0
# boat-neck       full sleeves      1774.0    8436  5630.0  15808.0
#                 short              213.0    1466  1240.0   4112.0
#                 sleeve less        797.0    3130  2395.0   8048.0
# bowneck         full sleeves        68.0     273   221.0    746.0
#                 half sleeves         1.0       5     4.0     21.0
#                 short               62.0     430   420.0   1154.0
#                 sleeve less       1194.0    3875  2709.0  10450.0
# halter          sleeve less        151.0     505   363.0   1336.0
# mandarin-collor half sleeves        15.0      63    53.0    158.0
# o-neck          Petal              750.0    6216  6405.0  17311.0
# ...

# %%
# Group "Sleeve length" categories into "Others" which have less than 50000 sales across all the seasons.
totsleeve = inp0.groupby(by=['SleeveLength'])[['Summer','Spring','Winter','Autumn']].sum()
totsleeve
# Out:
#                   Summer   Spring    Winter    Autumn
# SleeveLength
# Petal               6216    750.0    6405.0   17311.0
# butterfly           7706   1396.0    5678.0   14676.0
# cap sleeves         2892    924.0    1974.0    7813.0
# full sleeves      116794  25036.0   80314.0  233350.0
# half sleeves       55133  11843.0   35812.0  105055.0
# short             186363  37439.0  124509.0  347819.0
# sleeve less       242286  50927.0  171075.0  501247.0
# three quater       64312  13066.0   41802.0  114363.0
# turn down collar     733    160.0     632.0    2058.0

# %%
totsleeve[totsleeve.sum(axis=1)<50000]
# Out:
#                   Summer  Spring  Winter   Autumn
# SleeveLength
# Petal               6216   750.0  6405.0  17311.0
# butterfly           7706  1396.0  5678.0  14676.0
# cap sleeves         2892   924.0  1974.0   7813.0
# turn down collar     733   160.0   632.0   2058.0

# %% [markdown]
# Club material, fabrictype, patterntype and decoration categories into "Others" which have less than 25000 sales across all the seasons

# %%
# Group "material" categories into "Others" which have less than 25000 sales across all the seasons.
totmat = inp0.groupby(by=['Material'])[['Summer','Spring','Winter','Autumn']].sum()
totmat
# Out:
#                Summer   Spring    Winter    Autumn
# Material
# Missing        172775  35006.0  118652.0  336779.0
# acrylic          2822    749.0    1956.0    6628.0
# cashmere         1450    312.0     985.0    2920.0
# chiffonfabric   92292  20019.0   57014.0  163959.0
# cotton         186262  38460.0  129821.0  372874.0
# lace             1773    350.0    1127.0    3046.0
# linen            5357   1061.0    3723.0   10008.0
# lycra            3224    559.0    2389.0    6383.0
# microfiber       6454    825.0    6571.0   17967.0
# milksilk         8772   1807.0    6024.0   17107.0
# mix             17684   3266.0   12723.0   34817.0
# modal             147     31.0      95.0     249.0
# model              50      8.0      43.0     144.0
# nylon            6576   1705.0    4781.0   16421.0
# other            1153    307.0     901.0    3097.0
# polyster       125980  26156.0   87241.0  248502.0
# rayon           17819   3747.0   11331.0   32311.0
# ...

# %%
totmat[totmat.sum(axis=1)<25000]
# Out:
#           Summer  Spring  Winter   Autumn
# Material
# acrylic     2822   749.0  1956.0   6628.0
# cashmere    1450   312.0   985.0   2920.0
# lace        1773   350.0  1127.0   3046.0
# linen       5357  1061.0  3723.0  10008.0
# lycra       3224   559.0  2389.0   6383.0
# modal        147    31.0    95.0    249.0
# model         50     8.0    43.0    144.0
# other       1153   307.0   901.0   3097.0
# shiffon     1877   490.0  1353.0   4575.0
# sill         532    11.0   662.0   1514.0
# spandex     5930  1215.0  3924.0  11333.0
# viscos       897   300.0   576.0   2407.0
# wool         159    28.0   150.0    522.0

# %%
# Group "fabric type" categories into "Others" which have less than 25000 sales across all the seasons.
totfabric = inp0.groupby(by=['FabricType'])[['Summer','Spring','Winter','Autumn']].sum()
totfabric
# Out:
#             Summer   Spring    Winter    Autumn
# FabricType
# Corduroy      2279    688.0    1640.0    6259.0
# Missing     310173  64656.0  216901.0  626217.0
# batik          864     98.0     854.0    2205.0
# broadcloth   30718   6149.0   21585.0   61546.0
# chiffon     265067  54883.0  176263.0  502947.0
# dobby          744    146.0     497.0    1374.0
# flannael      1751    321.0    1301.0    3462.0
# flannel       4289    854.0    2595.0    6995.0
# jersey       32635   6457.0   21500.0   59360.0
# knitted          3      1.0       2.0       8.0
# knitting         9      2.0       7.0      21.0
# lace           446    141.0     309.0    1186.0
# organza        160     51.0     109.0     442.0
# other          264     25.0     284.0     678.0
# poplin         333     84.0     239.0     787.0
# satin         2376    341.0    2807.0    5879.0
# sattin        1986    456.0    1651.0    5580.0
# shiffon       6170   1688.0    4324.0   15304.0
# ...

# %%
totfabric[totfabric.sum(axis=1)<25000]
# Out:
#             Summer  Spring  Winter  Autumn
# FabricType
# Corduroy      2279   688.0  1640.0  6259.0
# batik          864    98.0   854.0  2205.0
# dobby          744   146.0   497.0  1374.0
# flannael      1751   321.0  1301.0  3462.0
# flannel       4289   854.0  2595.0  6995.0
# knitted          3     1.0     2.0     8.0
# knitting         9     2.0     7.0    21.0
# lace           446   141.0   309.0  1186.0
# organza        160    51.0   109.0   442.0
# other          264    25.0   284.0   678.0
# poplin         333    84.0   239.0   787.0
# satin         2376   341.0  2807.0  5879.0
# sattin        1986   456.0  1651.0  5580.0
# terry           80    25.0    60.0   208.0
# tulle          439   136.0   313.0  1231.0
# wollen         600   184.0   416.0  1658.0

# %%
# Group "patern type" categories into "Others" which have less than 25000 sales across all the seasons.
totpattern = inp0.groupby(by=['Pattern Type'])[['Summer','Spring','Winter','Autumn']].sum()
totpattern
# Out:
#               Summer   Spring    Winter    Autumn
# Pattern Type
# Missing Type   58662  14508.0   40719.0  133793.0
# animal         53975   9969.0   39725.0  107604.0
# character        993    176.0     728.0    1841.0
# dot            70367  14173.0   43181.0  117370.0
# floral          2807    534.0    1933.0    5340.0
# geometric      33000   6584.0   20620.0   54131.0
# leapord          623    124.0     538.0    1732.0
# leopard         6912   1164.0    5022.0   12169.0
# none            1291    389.0     951.0    3360.0
# patchwork      48402  10224.0   33501.0   98233.0
# plaid            346     64.0     256.0     703.0
# print         105061  20917.0   72677.0  204370.0
# solid         283496  59507.0  196353.0  567694.0
# splice          1042    270.0     810.0    2990.0
# striped        15458   2938.0   11187.0   32362.0

# %%
totpattern[totpattern.sum(axis=1)<25000]
# Out:
#               Summer  Spring  Winter  Autumn
# Pattern Type
# character        993   176.0   728.0  1841.0
# floral          2807   534.0  1933.0  5340.0
# leapord          623   124.0   538.0  1732.0
# none            1291   389.0   951.0  3360.0
# plaid            346    64.0   256.0   703.0
# splice          1042   270.0   810.0  2990.0

# %%
# Group "decoration" categories into "Others" which have less than 25000 sales across all the seasons.
totdecor = inp0.groupby(by=['Decoration'])[['Summer','Spring','Winter','Autumn']].sum()
totdecor
# Out:
#             Summer   Spring    Winter    Autumn
# Decoration
# Missing     277261  58641.0  191284.0  557288.0
# Tiered        6366   1268.0    3910.0   10603.0
# applique     17207   3356.0   12448.0   34862.0
# beading      11737   2425.0    8839.0   25910.0
# bow          72872  15114.0   44467.0  122906.0
# button        5390    998.0    4200.0   11615.0
# cascading       42      8.0      34.0     126.0
# crystal       1346    420.0     940.0    3744.0
# draped        1572    550.0    1054.0    3923.0
# embroidary   10485   1888.0    7803.0   21692.0
# feathers        14      3.0      12.0      35.0
# flowers       1502    426.0    1046.0    3702.0
# hollowout    16397   3267.0   12287.0   35807.0
# lace        112519  23039.0   76116.0  212914.0
# none           737    217.0     538.0    2059.0
# pearls           8      2.0       7.0      24.0
# plain          573    168.0     399.0    1600.0
# pockets       5605   1149.0    3891.0   10887.0
# ...

# %%
totdecor[totdecor.sum(axis=1)<25000]
# Out:
#             Summer  Spring  Winter   Autumn
# Decoration
# Tiered        6366  1268.0  3910.0  10603.0
# button        5390   998.0  4200.0  11615.0
# cascading       42     8.0    34.0    126.0
# crystal       1346   420.0   940.0   3744.0
# draped        1572   550.0  1054.0   3923.0
# feathers        14     3.0    12.0     35.0
# flowers       1502   426.0  1046.0   3702.0
# none           737   217.0   538.0   2059.0
# pearls           8     2.0     7.0     24.0
# plain          573   168.0   399.0   1600.0
# pockets       5605  1149.0  3891.0  10887.0
# rivet         3905  1225.0  2605.0  10066.0
# ruched        1676   526.0  1164.0   4574.0
# tassel         181    42.0   154.0    562.0

# %% [markdown]
# ### Caregorical Ordered Univariate Analysis

# %% [markdown]
# Which of the following is an unordered variable in “Attribute DataSet”.
# - Style
# - Price
# - Season
# - Size

# %% [markdown]
# ### Numerical variable Univariate analysis:

# %% [markdown]
# What is the approximate difference between the maximum value and 75th percentile in “Autumn” column.
# - Approx 54000
# - Approx 55000
# - Approx 52000
# - Approx 50000

# %%
# Describe the numerical variale: "Autumn".
inp0.describe()
# Out:
#            Dress_ID      Rating  Recommendation       Spring        Summer  \
# count  4.710000e+02  471.000000      471.000000   471.000000    471.000000
# mean   9.024773e+08    3.491932        0.422505   300.511677   1448.906582
# std    1.829438e+08    2.029982        0.494483   605.470114   2995.940755
# min    1.234568e+08    0.000000        0.000000     1.000000      2.000000
# 25%    7.666611e+08    2.000000        0.000000    28.500000    156.500000
# 50%    9.110851e+08    4.600000        0.000000   112.000000    518.000000
# 75%    1.039684e+09    4.800000        1.000000   308.500000   1475.500000
# max    1.253973e+09    5.000000        1.000000  7374.000000  35577.000000
#
#              Winter        Autumn
# count    471.000000    471.000000
# mean     994.057325   2852.849257
# std     1861.825104   5037.033044
# min        0.000000      1.000000
# 25%      122.000000    410.500000
# 50%      402.000000   1334.000000
# 75%     1096.000000   3126.000000
# ...

# %%
# plot the boxplot of "Autumn" column.
plt.figure(figsize=(5,5))
sns.boxplot(inp0['Autumn'])
plt.show()

# %% [markdown]
# Which of the following season has the highest difference between the maximum value and 99th quantile of sales?
# - Winter
# - Summer
# - Spring
# - Autumn

# %%
# Find the maximum and 99th percentile of Winter season.
inp0['Winter'].quantile([0.99,1])
# Out:
# 0.99     8985.3
# 1.00    20388.0
# Name: Winter, dtype: float64

# %%
# Find the maximum and 99th percentile of Summer season.
inp0['Summer'].quantile([0.99,1])
# Out:
# 0.99    13974.0
# 1.00    35577.0
# Name: Summer, dtype: float64

# %%
# Find the maximum and 99th percentile of Spring season.
inp0['Spring'].quantile([0.99,1])
# Out:
# 0.99    2657.2
# 1.00    7374.0
# Name: Spring, dtype: float64

# %%
# Find the maximum and 99th percentile of Autumn season.
inp0['Autumn'].quantile([0.99,1])
# Out:
# 0.99    24134.0
# 1.00    55532.0
# Name: Autumn, dtype: float64

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Numerical- Categorical analysis

# %% [markdown]
# Which of the following “Price” category has the lowest average value of rating?
# - very-high
# - Medium
# - Low
# - High

# %%
inp0.dtypes
# Out:
# Dress_ID            int64
# Style              object
# Price              object
# Rating            float64
# Size               object
# Season             object
# NeckLine           object
# SleeveLength       object
# Material           object
# FabricType         object
# Decoration         object
# Pattern Type       object
# Recommendation      int64
# Spring            float64
# Summer              int64
# Winter            float64
# Autumn            float64
# dtype: object

# %%
# Find the Mean of Ratings for each Price category.
inp0.groupby('Price')['Rating'].mean()
# Out:
# Price
# Average      3.454430
# High         2.914286
# Low          3.731481
# Medium       3.156667
# very-high    3.123810
# Name: Rating, dtype: float64

# %% [markdown]
# What is the median of the rating of “vintage” category in Style column?
# - 4.6
# - 4.7
# - 4.55
# - 0.00

# %%
# Find the median of Ratings for each Style category.
inp0.groupby('Style')['Rating'].median()
# Out:
# Style
# Brief       4.60
# Casual      4.60
# Flare       0.00
# Novelty     2.10
# OL          0.00
# Sexy        4.60
# bohemian    4.60
# cute        4.60
# fashion     4.00
# party       4.70
# sexy        4.55
# vintage     4.60
# work        4.70
# Name: Rating, dtype: float64

# %% [markdown]
# Which of the following season has the highest average value of sale for “Recommendation” value equals to 1.
# - Summer
# - Spring
# - Autumn
# - Winter

# %%
inp0.groupby('Season')['Recommendation'].mean()
# Out:
# Season
# Autumn    0.333333
# Spring    0.601695
# Summer    0.337748
# Winter    0.404412
# Name: Recommendation, dtype: float64

# %%
sns.barplot(x=inp0['Recommendation'],y=inp0['Season'])
plt.show()

# %%
# Summer sale vs Recommendation.
inp0[inp0["Recommendation"]==1].Summer.mean()
# Out:
# 1469.8994974874372

# %%
# Spring sale vs Recommendation.
inp0[inp0["Recommendation"]==1].Spring.mean()
# Out:
# 303.65829145728645

# %%
# Autumn sale vs Recommendation.
inp0[inp0["Recommendation"]==1].Autumn.mean()
# Out:
# 2868.0603015075376

# %%
# Winter sale vs Recommendation.
inp0[inp0["Recommendation"]==1].Winter.mean()
# Out:
# 1002.8090452261307

# %% [markdown]
# ### Categorical categorical bivariate analysis

# %% [markdown]
# Which of the following size categories has the highest positive recommendations?
# - Medium and extra large
# - Extra large and small
# - Free and small
# - Free and medium

# %%
# Size vs Recommendation.
inp0.groupby('Size')['Recommendation'].mean()
# Out:
# Size
# Extra large    0.285714
# Free           0.456790
# Large          0.359551
# Medium         0.447059
# Small          0.361111
# Name: Recommendation, dtype: float64

# %% [markdown]
# ### Multivariate analysis

# %% [markdown]
# Which of the following pair of “Style” and “Price” category has the highest average of positive recommendations?
# - Price: medium and style: vintage
# - Price: medium and style: cute
# - Price: very high and style: party
# - Price: low and style: sexy

# %%
inp0.groupby(by=['Style','Price'])['Recommendation'].mean()
# Out:
# Style     Price
# Brief     Average      0.333333
#           Low          0.000000
# Casual    Average      0.345455
#           High         0.666667
#           Low          0.379310
#           Medium       0.666667
#           very-high    0.500000
# Flare     Average      0.500000
# Novelty   Average      0.400000
#           Medium       1.000000
# OL        Medium       0.000000
# Sexy      Average      0.344828
#           High         0.000000
#           Low          0.500000
#           Medium       0.000000
#           very-high    0.000000
# bohemian  Average      0.333333
#           Low          0.666667
#           Medium       1.000000
#           very-high    1.000000
# cute      Average      0.400000
#           High         0.666667
#           Low          0.500000
#           Medium       1.000000
# fashion   Average      0.000000
# party     Average      0.647059
#           High         0.333333
#           Medium       0.800000
# ...

# %%
# plot the heat map of Style, price and Recommendation.
res = pd.pivot_table(data=inp0, index="Style", columns="Price", values="Recommendation")
sns.heatmap(res, cmap="RdYlGn", annot=True, center=0.427)
plt.show()

# %% [markdown]
# Which of the following material type has no recommendation in summer and winter seasons?
# - Mix and Milksilk
# - Nylon and Rayon
# - Microfiber and Silk
# - Milksilk and Microfiber

# %%
# plot the heat map of Season, material and Recommendation.
inp0.groupby(by=['Season','Material'])['Recommendation'].mean()
# Out:
# Season  Material
# Autumn  Missing          0.428571
#         cashmere         0.000000
#         chiffonfabric    0.500000
#         cotton           0.294118
#         lace             0.000000
#         linen            0.000000
#         milksilk         1.000000
#         nylon            0.000000
#         polyster         0.266667
#         rayon            0.666667
#         silk             0.000000
# Spring  Missing          0.657143
#         acrylic          0.000000
#         chiffonfabric    0.600000
#         cotton           0.576923
#         lycra            1.000000
#         microfiber       1.000000
#         mix              0.500000
#         nylon            0.333333
#         polyster         0.571429
#         rayon            1.000000
#         shiffon          0.500000
#         silk             0.538462
#         spandex          0.500000
# Summer  Missing          0.454545
#         acrylic          0.000000
#         chiffonfabric    0.125000
# ...

# %%
res = pd.pivot_table(data=inp0, index="Material", columns="Season", values="Recommendation")
sns.heatmap(res, cmap="RdYlGn", annot=True)
plt.show()
